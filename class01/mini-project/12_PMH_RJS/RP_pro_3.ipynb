# %%
import time
from pathlib import Path

import cv2
import matplotlib.cm
import numpy as np
from IPython.display import display, clear_output, Audio
import openvino as ov
import ipywidgets as widgets
import os

from notebook_utils import download_file, load_image

# 모델 다운로드 및 로드
model_folder = Path("model")
ir_model_url_depth = "https://storage.openvinotoolkit.org/repositories/openvino_notebooks/models/depth-estimation-midas/FP32/"
ir_model_name_depth_xml = "MiDaS_small.xml"
ir_model_name_depth_bin = "MiDaS_small.bin"

ir_model_url_detection = "https://storage.openvinotoolkit.org/repositories/open_model_zoo/2021.4/models_bin/1/vehicle-detection-adas-0002/FP32/"
ir_model_name_detection_xml = "vehicle-detection-adas-0002.xml"
ir_model_name_detection_bin = "vehicle-detection-adas-0002.bin"

download_file(ir_model_url_depth + ir_model_name_depth_xml, filename=ir_model_name_depth_xml, directory=model_folder)
download_file(ir_model_url_depth + ir_model_name_depth_bin, filename=ir_model_name_depth_bin, directory=model_folder)
download_file(ir_model_url_detection + ir_model_name_detection_xml, filename=ir_model_name_detection_xml, directory=model_folder)
download_file(ir_model_url_detection + ir_model_name_detection_bin, filename=ir_model_name_detection_bin, directory=model_folder)

model_depth_xml_path = model_folder / ir_model_name_depth_xml
model_detection_xml_path = model_folder / ir_model_name_detection_xml

def normalize_minmax(data):
    """Normalizes the values in `data` between 0 and 1"""
    return (data - data.min()) / (data.max() - data.min())

def convert_result_to_image(result, colormap="viridis"):
    """
    Convert network result of floating point numbers to an RGB image with
    integer values from 0-255 by applying a colormap.

    `result` is expected to be a single network result in 1,H,W shape
    `colormap` is a matplotlib colormap.
    See https://matplotlib.org/stable/tutorials/colors/colormaps.html
    """
    cmap = matplotlib.cm.get_cmap(colormap)
    result = result.squeeze(0)
    result = normalize_minmax(result)
    result = cmap(result)[:, :, :3] * 255
    result = result.astype(np.uint8)
    return result

def to_rgb(image_data) -> np.ndarray:
    """Convert image_data from BGR to RGB"""
    return cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)

def play_warning_sound():
    """Play a warning sound"""
    duration = 1  # seconds
    freq = 440  # Hz
    os.system('play -nq -t alsa synth {} sine {}'.format(duration, freq))

def sound(sound_file):
    wn = Audio(sound_file, autoplay=True)
    display(wn)


# OpenVINO Core 초기화 및 모델 컴파일
core = ov.Core()
device = widgets.Dropdown(
    options=core.available_devices + ["AUTO"],
    value="AUTO",
    description="Device:",
    disabled=False,
)

# Create cache folder
cache_folder = Path("cache")
cache_folder.mkdir(exist_ok=True)

core.set_property({"CACHE_DIR": cache_folder})

# 깊이 맵 모델 컴파일
model_depth = core.read_model(model_depth_xml_path)
compiled_model_depth = core.compile_model(model=model_depth, device_name=device.value)

input_key_depth = compiled_model_depth.input(0)
output_key_depth = compiled_model_depth.output(0)

network_input_shape_depth = list(input_key_depth.shape)
network_image_height_depth, network_image_width_depth = network_input_shape_depth[2:]

# 차량 감지 모델 컴파일
model_detection = core.read_model(model_detection_xml_path)
compiled_model_detection = core.compile_model(model=model_detection, device_name=device.value)

input_key_detection = compiled_model_detection.input(0)
output_key_detection = compiled_model_detection.output(0)

network_input_shape_detection = list(input_key_detection.shape)
network_image_height_detection, network_image_width_detection = network_input_shape_detection[2:]

# 실시간 웹캠 피드와 거리 측정 및 차량 감지
# cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture("/home/ubuntu/Videos/Screencasts/ch4.webm")
fps = 25  # 목표 프레임 속도 (FPS)
frame_time = 1.0 / fps  # 한 프레임의 시간 (초)


paused = False
paused_frame = None
alarm_triggered = False  # 경고음을 재생했는지 추적하는 변수
frame_count = 0
consecutive_depth_count = 0  # 연속된 깊이 값이 200을 초과하는 경우의 횟수를 추적하는 변수

while cap.isOpened():
    start_time = time.time()
    if not paused:
        ret, frame = cap.read()
        if not ret:
            break
        # 차량 감지
        resized_image_detection = cv2.resize(src=frame, dsize=(network_image_width_detection, network_image_height_detection))
        input_image_detection = np.expand_dims(np.transpose(resized_image_detection, (2, 0, 1)), 0)
        result_detection = compiled_model_detection([input_image_detection])[output_key_detection]
        # 화면 가운데 좌표 (중앙선 위치)
        center_x_line = frame.shape[1]*0.6

        # 목록으로 깊이 값 저장
        depth_values = []
        
        # 차량 감지 결과 표시
        for detection in result_detection[0][0]:
            confidence = detection[2]
            if confidence > 0.5:  # 감지 신뢰도가 50% 이상인 경우
                xmin = int(detection[3] * frame.shape[1])
                ymin = int(detection[4] * frame.shape[0])
                xmax = int(detection[5] * frame.shape[1])
                ymax = int(detection[6] * frame.shape[0])
                
                # 감지된 차량 영역의 중심점 계산
                center_x = (xmin + xmax) // 2
                center_y = (ymin + ymax) // 2
                
                if center_x < center_x_line:
                    cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)
                    #cv2.putText(frame, f'Confidence: {confidence:.2f}', (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                    # 중심점 좌표를 이용하여 깊이(거리) 추정
                    resized_image_depth = cv2.resize(src=frame, dsize=(network_image_width_depth, network_image_height_depth))
                    input_image_depth = np.expand_dims(np.transpose(resized_image_depth, (2, 0, 1)), 0)
                    result_depth = compiled_model_depth([input_image_depth])[output_key_depth]
    
                    # 결과 이미지를 컬러맵으로 변환
                    result_image = convert_result_to_image(result=result_depth)
                    
                    # 원본 이미지 크기로 다시 조정
                    result_image = cv2.resize(result_image, frame.shape[:2][::-1])
                    
                    result_depth_rescaled = cv2.resize(result_depth[0], (frame.shape[1], frame.shape[0]))
                    
                    depth_value = result_depth_rescaled[center_y, center_x]  # 수정된 부분
                    cv2.putText(frame, f'Distance: {depth_value:.2f}', (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                    print(f"Detected vehicle depth at center: {depth_value}")
                    depth_values.append(depth_value)  # 깊이 값을 리스트에 추가
        
        # 리스트에서 최대 깊이 값 찾기
        if depth_values:
            max_depth_value = max(depth_values)
            print(f"Maximum depth value among detected vehicles: {max_depth_value}")
            if max_depth_value > 200.0:
                consecutive_depth_count += 1
                if consecutive_depth_count >= 5:
                    cv2.putText(frame, 'Danger!!', (frame.shape[1] // 4, frame.shape[0] // 2), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                    if not alarm_triggered:  # 경고음이 아직 재생되지 않은 경우에만 재생
                        sound("./danger.mp3")
                        alarm_triggered = True
            else:
                alarm_triggered = False  # 조건이 만족되지 않으면 경고음 상태를 초기화
                consecutive_depth_count = 0 
        else:
            print("No vehicles detected.")
            alarm_triggered = False  # 차량이 감지되지 않으면 경고음 상태를 초기화
            consecutive_depth_count = 0 

        # 프레임을 일시정지 상태에서 사용할 수 있도록 저장
        paused_frame = frame.copy()
        
    else:
        # 일시정지 상태에서는 저장된 프레임을 표시
        if paused_frame is not None:
            frame = paused_frame
    
    # combined_image = np.hstack((frame, result_image))
    cv2.imshow('Object Detection and Depth Estimation', frame)
    
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break
    elif key == ord('p'):
        paused = not paused
        if paused:
            print("Paused")
        else:
            print("Resumed")

    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time < frame_time:
        time.sleep(frame_time - elapsed_time)

cap.release()
cv2.destroyAllWindows()
# Out:
# 'model/MiDaS_small.xml' already exists.
# 'model/MiDaS_small.bin' already exists.
# 'model/vehicle-detection-adas-0002.xml' already exists.
# 'model/vehicle-detection-adas-0002.bin' already exists.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# Detected vehicle depth at center: 120.12142181396484
# Maximum depth value among detected vehicles: 120.12142181396484
# Detected vehicle depth at center: 120.80329132080078
# Maximum depth value among detected vehicles: 120.80329132080078
# Detected vehicle depth at center: 121.67041778564453
# Maximum depth value among detected vehicles: 121.67041778564453
# Detected vehicle depth at center: 120.62772369384766
# Maximum depth value among detected vehicles: 120.62772369384766
# Detected vehicle depth at center: 121.50696563720703
# Maximum depth value among detected vehicles: 121.50696563720703
# Detected vehicle depth at center: 123.7304458618164
# Maximum depth value among detected vehicles: 123.7304458618164
# Detected vehicle depth at center: 118.69318389892578
# Maximum depth value among detected vehicles: 118.69318389892578
# Detected vehicle depth at center: 120.87691497802734
# Maximum depth value among detected vehicles: 120.87691497802734
# Detected vehicle depth at center: 119.01634216308594
# Maximum depth value among detected vehicles: 119.01634216308594
# Detected vehicle depth at center: 115.84414672851562
# Maximum depth value among detected vehicles: 115.84414672851562
# Detected vehicle depth at center: 118.22645568847656
# Maximum depth value among detected vehicles: 118.22645568847656
# Detected vehicle depth at center: 117.13432312011719
# Maximum depth value among detected vehicles: 117.13432312011719
# Detected vehicle depth at center: 120.14225006103516
# Maximum depth value among detected vehicles: 120.14225006103516
# Detected vehicle depth at center: 120.09535217285156
# Maximum depth value among detected vehicles: 120.09535217285156
# Detected vehicle depth at center: 132.495849609375
# Maximum depth value among detected vehicles: 132.495849609375
# No vehicles detected.
# Detected vehicle depth at center: 143.51568603515625
# Maximum depth value among detected vehicles: 143.51568603515625
# No vehicles detected.
# Detected vehicle depth at center: 137.733642578125
# Maximum depth value among detected vehicles: 137.733642578125
# Detected vehicle depth at center: 142.28121948242188
# Maximum depth value among detected vehicles: 142.28121948242188
# Detected vehicle depth at center: 135.80697631835938
# Maximum depth value among detected vehicles: 135.80697631835938
# Detected vehicle depth at center: 131.30892944335938
# Maximum depth value among detected vehicles: 131.30892944335938
# Detected vehicle depth at center: 135.29229736328125
# Maximum depth value among detected vehicles: 135.29229736328125
# Detected vehicle depth at center: 128.2206268310547
# Maximum depth value among detected vehicles: 128.2206268310547
# Detected vehicle depth at center: 131.615234375
# Maximum depth value among detected vehicles: 131.615234375
# Detected vehicle depth at center: 128.27650451660156
# Maximum depth value among detected vehicles: 128.27650451660156
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# Detected vehicle depth at center: 134.82894897460938
# Maximum depth value among detected vehicles: 134.82894897460938
# Detected vehicle depth at center: 139.9509735107422
# Maximum depth value among detected vehicles: 139.9509735107422
# Detected vehicle depth at center: 142.53176879882812
# Maximum depth value among detected vehicles: 142.53176879882812
# Detected vehicle depth at center: 140.01638793945312
# Maximum depth value among detected vehicles: 140.01638793945312
# Detected vehicle depth at center: 143.69293212890625
# Maximum depth value among detected vehicles: 143.69293212890625
# Detected vehicle depth at center: 155.83621215820312
# Maximum depth value among detected vehicles: 155.83621215820312
# Detected vehicle depth at center: 152.60646057128906
# Maximum depth value among detected vehicles: 152.60646057128906
# Detected vehicle depth at center: 153.53158569335938
# Maximum depth value among detected vehicles: 153.53158569335938
# Detected vehicle depth at center: 147.67153930664062
# Maximum depth value among detected vehicles: 147.67153930664062
# Detected vehicle depth at center: 154.40208435058594
# Maximum depth value among detected vehicles: 154.40208435058594
# Detected vehicle depth at center: 147.80624389648438
# Maximum depth value among detected vehicles: 147.80624389648438
# No vehicles detected.
# Detected vehicle depth at center: 148.00975036621094
# Maximum depth value among detected vehicles: 148.00975036621094
# Detected vehicle depth at center: 152.48072814941406
# Maximum depth value among detected vehicles: 152.48072814941406
# Detected vehicle depth at center: 150.20391845703125
# Maximum depth value among detected vehicles: 150.20391845703125
# Detected vehicle depth at center: 152.83106994628906
# Maximum depth value among detected vehicles: 152.83106994628906
# Detected vehicle depth at center: 146.40049743652344
# Maximum depth value among detected vehicles: 146.40049743652344
# Detected vehicle depth at center: 156.87802124023438
# Maximum depth value among detected vehicles: 156.87802124023438
# Detected vehicle depth at center: 151.6016845703125
# Maximum depth value among detected vehicles: 151.6016845703125
# Detected vehicle depth at center: 158.320556640625
# Maximum depth value among detected vehicles: 158.320556640625
# Detected vehicle depth at center: 155.12619018554688
# Maximum depth value among detected vehicles: 155.12619018554688
# Detected vehicle depth at center: 164.80886840820312
# Maximum depth value among detected vehicles: 164.80886840820312
# Detected vehicle depth at center: 152.34359741210938
# Maximum depth value among detected vehicles: 152.34359741210938
# Detected vehicle depth at center: 147.32562255859375
# Detected vehicle depth at center: 120.94902038574219
# Maximum depth value among detected vehicles: 147.32562255859375
# Detected vehicle depth at center: 145.48355102539062
# Detected vehicle depth at center: 121.07424926757812
# Maximum depth value among detected vehicles: 145.48355102539062
# Detected vehicle depth at center: 153.6165008544922
# Detected vehicle depth at center: 134.12130737304688
# Maximum depth value among detected vehicles: 153.6165008544922
# Detected vehicle depth at center: 149.77976989746094
# Detected vehicle depth at center: 135.42333984375
# Maximum depth value among detected vehicles: 149.77976989746094
# Detected vehicle depth at center: 152.63844299316406
# Detected vehicle depth at center: 134.3831787109375
# Maximum depth value among detected vehicles: 152.63844299316406
# Detected vehicle depth at center: 149.48667907714844
# Detected vehicle depth at center: 127.5139389038086
# Maximum depth value among detected vehicles: 149.48667907714844
# Detected vehicle depth at center: 146.82546997070312
# Detected vehicle depth at center: 130.941162109375
# Maximum depth value among detected vehicles: 146.82546997070312
# Detected vehicle depth at center: 154.7361297607422
# Detected vehicle depth at center: 127.2597885131836
# Maximum depth value among detected vehicles: 154.7361297607422
# Detected vehicle depth at center: 150.4593963623047
# Maximum depth value among detected vehicles: 150.4593963623047
# Detected vehicle depth at center: 143.42282104492188
# Maximum depth value among detected vehicles: 143.42282104492188
# Detected vehicle depth at center: 147.14013671875
# Maximum depth value among detected vehicles: 147.14013671875
# Detected vehicle depth at center: 108.24724578857422
# Maximum depth value among detected vehicles: 108.24724578857422
# Detected vehicle depth at center: 160.8115234375
# Detected vehicle depth at center: 110.311279296875
# Maximum depth value among detected vehicles: 160.8115234375
# Detected vehicle depth at center: 175.0194091796875
# Detected vehicle depth at center: 127.51715087890625
# Maximum depth value among detected vehicles: 175.0194091796875
# Detected vehicle depth at center: 170.9542999267578
# Detected vehicle depth at center: 124.56844329833984
# Maximum depth value among detected vehicles: 170.9542999267578
# Detected vehicle depth at center: 165.8903045654297
# Detected vehicle depth at center: 122.19798278808594
# Maximum depth value among detected vehicles: 165.8903045654297
# Detected vehicle depth at center: 156.8899383544922
# Detected vehicle depth at center: 125.2347640991211
# Maximum depth value among detected vehicles: 156.8899383544922
# Detected vehicle depth at center: 174.5623779296875
# Detected vehicle depth at center: 113.21353149414062
# Maximum depth value among detected vehicles: 174.5623779296875
# Detected vehicle depth at center: 167.25714111328125
# Detected vehicle depth at center: 114.25717163085938
# Maximum depth value among detected vehicles: 167.25714111328125
# Detected vehicle depth at center: 103.04544067382812
# Detected vehicle depth at center: 160.72671508789062
# Maximum depth value among detected vehicles: 160.72671508789062
# Detected vehicle depth at center: 182.55496215820312
# Detected vehicle depth at center: 121.60664367675781
# Maximum depth value among detected vehicles: 182.55496215820312
# Detected vehicle depth at center: 163.55567932128906
# Detected vehicle depth at center: 116.89046478271484
# Maximum depth value among detected vehicles: 163.55567932128906
# Detected vehicle depth at center: 157.20396423339844
# Detected vehicle depth at center: 115.97906494140625
# Maximum depth value among detected vehicles: 157.20396423339844
# Detected vehicle depth at center: 176.20492553710938
# Detected vehicle depth at center: 124.22281646728516
# Maximum depth value among detected vehicles: 176.20492553710938
# Detected vehicle depth at center: 167.28457641601562
# Detected vehicle depth at center: 112.12726593017578
# Maximum depth value among detected vehicles: 167.28457641601562
# Detected vehicle depth at center: 156.99832153320312
# Detected vehicle depth at center: 125.86272430419922
# Maximum depth value among detected vehicles: 156.99832153320312
# Detected vehicle depth at center: 161.33897399902344
# Detected vehicle depth at center: 135.48085021972656
# Maximum depth value among detected vehicles: 161.33897399902344
# Detected vehicle depth at center: 145.43638610839844
# Maximum depth value among detected vehicles: 145.43638610839844
# Detected vehicle depth at center: 167.2062530517578
# Detected vehicle depth at center: 141.8403778076172
# Maximum depth value among detected vehicles: 167.2062530517578
# Detected vehicle depth at center: 170.2526092529297
# Detected vehicle depth at center: 135.75193786621094
# Maximum depth value among detected vehicles: 170.2526092529297
# Detected vehicle depth at center: 178.1073455810547
# Detected vehicle depth at center: 139.24661254882812
# Maximum depth value among detected vehicles: 178.1073455810547
# Detected vehicle depth at center: 186.80406188964844
# Detected vehicle depth at center: 136.15650939941406
# Maximum depth value among detected vehicles: 186.80406188964844
# Detected vehicle depth at center: 201.25698852539062
# Detected vehicle depth at center: 150.79110717773438
# Maximum depth value among detected vehicles: 201.25698852539062
# Detected vehicle depth at center: 202.35885620117188
# Detected vehicle depth at center: 165.42098999023438
# Maximum depth value among detected vehicles: 202.35885620117188
# Detected vehicle depth at center: 218.5386505126953
# Detected vehicle depth at center: 159.4989776611328
# Maximum depth value among detected vehicles: 218.5386505126953
# Detected vehicle depth at center: 192.5219268798828
# Detected vehicle depth at center: 146.01185607910156
# Maximum depth value among detected vehicles: 192.5219268798828
# Detected vehicle depth at center: 204.822265625
# Detected vehicle depth at center: 159.5919189453125
# Maximum depth value among detected vehicles: 204.822265625
# Detected vehicle depth at center: 223.43130493164062
# Detected vehicle depth at center: 165.48892211914062
# Maximum depth value among detected vehicles: 223.43130493164062
# Detected vehicle depth at center: 236.61744689941406
# Detected vehicle depth at center: 193.6999053955078
# Maximum depth value among detected vehicles: 236.61744689941406
# Detected vehicle depth at center: 255.616455078125
# Maximum depth value among detected vehicles: 255.616455078125
# Detected vehicle depth at center: 216.8520050048828
# Detected vehicle depth at center: 154.17189025878906
# Maximum depth value among detected vehicles: 216.8520050048828
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Detected vehicle depth at center: 206.07305908203125
# Detected vehicle depth at center: 152.9791259765625
# Maximum depth value among detected vehicles: 206.07305908203125
# Detected vehicle depth at center: 268.85003662109375
# Maximum depth value among detected vehicles: 268.85003662109375
# Detected vehicle depth at center: 289.6913757324219
# Detected vehicle depth at center: 161.19638061523438
# Maximum depth value among detected vehicles: 289.6913757324219
# Detected vehicle depth at center: 254.72314453125
# Detected vehicle depth at center: 163.56625366210938
# Maximum depth value among detected vehicles: 254.72314453125
# Detected vehicle depth at center: 273.6822509765625
# Detected vehicle depth at center: 159.28468322753906
# Maximum depth value among detected vehicles: 273.6822509765625
# Detected vehicle depth at center: 270.0695495605469
# Detected vehicle depth at center: 162.67520141601562
# Maximum depth value among detected vehicles: 270.0695495605469
# Detected vehicle depth at center: 271.866455078125
# Detected vehicle depth at center: 162.6765899658203
# Maximum depth value among detected vehicles: 271.866455078125
# Detected vehicle depth at center: 312.3608703613281
# Detected vehicle depth at center: 170.74111938476562
# Maximum depth value among detected vehicles: 312.3608703613281
# Detected vehicle depth at center: 283.00823974609375
# Detected vehicle depth at center: 163.8560333251953
# Maximum depth value among detected vehicles: 283.00823974609375
# Detected vehicle depth at center: 364.90045166015625
# Detected vehicle depth at center: 180.36941528320312
# Maximum depth value among detected vehicles: 364.90045166015625
# Detected vehicle depth at center: 348.52362060546875
# Detected vehicle depth at center: 187.4190673828125
# Maximum depth value among detected vehicles: 348.52362060546875
# Detected vehicle depth at center: 371.33441162109375
# Detected vehicle depth at center: 168.49058532714844
# Maximum depth value among detected vehicles: 371.33441162109375
# Detected vehicle depth at center: 418.6673278808594
# Detected vehicle depth at center: 162.22315979003906
# Maximum depth value among detected vehicles: 418.6673278808594
# Detected vehicle depth at center: 388.34649658203125
# Detected vehicle depth at center: 162.63644409179688
# Maximum depth value among detected vehicles: 388.34649658203125
# Detected vehicle depth at center: 435.30474853515625
# Detected vehicle depth at center: 175.40638732910156
# Maximum depth value among detected vehicles: 435.30474853515625
# Detected vehicle depth at center: 419.864501953125
# Detected vehicle depth at center: 168.05418395996094
# Maximum depth value among detected vehicles: 419.864501953125
# Detected vehicle depth at center: 433.93096923828125
# Detected vehicle depth at center: 148.76356506347656
# Maximum depth value among detected vehicles: 433.93096923828125
# Detected vehicle depth at center: 438.83697509765625
# Detected vehicle depth at center: 171.88519287109375
# Maximum depth value among detected vehicles: 438.83697509765625
# Detected vehicle depth at center: 455.9296569824219
# Detected vehicle depth at center: 181.17234802246094
# Maximum depth value among detected vehicles: 455.9296569824219
# Detected vehicle depth at center: 446.31939697265625
# Detected vehicle depth at center: 170.93975830078125
# Maximum depth value among detected vehicles: 446.31939697265625
# Detected vehicle depth at center: 179.25308227539062
# Detected vehicle depth at center: 433.85394287109375
# Maximum depth value among detected vehicles: 433.85394287109375
# Detected vehicle depth at center: 467.5671691894531
# Detected vehicle depth at center: 157.91464233398438
# Maximum depth value among detected vehicles: 467.5671691894531
# Detected vehicle depth at center: 458.5970153808594
# Detected vehicle depth at center: 165.21627807617188
# Maximum depth value among detected vehicles: 458.5970153808594
# Detected vehicle depth at center: 432.87591552734375
# Detected vehicle depth at center: 156.1737518310547
# Maximum depth value among detected vehicles: 432.87591552734375
# Detected vehicle depth at center: 162.62106323242188
# Detected vehicle depth at center: 433.4913330078125
# Maximum depth value among detected vehicles: 433.4913330078125
# Detected vehicle depth at center: 451.7674865722656
# Detected vehicle depth at center: 154.51023864746094
# Maximum depth value among detected vehicles: 451.7674865722656
# Detected vehicle depth at center: 463.2722473144531
# Detected vehicle depth at center: 155.50181579589844
# Maximum depth value among detected vehicles: 463.2722473144531
# Detected vehicle depth at center: 449.06854248046875
# Detected vehicle depth at center: 134.29202270507812
# Maximum depth value among detected vehicles: 449.06854248046875
# Detected vehicle depth at center: 477.5947265625
# Detected vehicle depth at center: 148.7508087158203
# Maximum depth value among detected vehicles: 477.5947265625
# Detected vehicle depth at center: 475.4683837890625
# Detected vehicle depth at center: 144.07801818847656
# Maximum depth value among detected vehicles: 475.4683837890625
# Detected vehicle depth at center: 445.1746826171875
# Detected vehicle depth at center: 158.9736328125
# Maximum depth value among detected vehicles: 445.1746826171875
# Detected vehicle depth at center: 476.55145263671875
# Maximum depth value among detected vehicles: 476.55145263671875
# Detected vehicle depth at center: 465.4530944824219
# Maximum depth value among detected vehicles: 465.4530944824219
# Detected vehicle depth at center: 497.4079284667969
# Detected vehicle depth at center: 144.00143432617188
# Maximum depth value among detected vehicles: 497.4079284667969
# Detected vehicle depth at center: 492.6810302734375
# Detected vehicle depth at center: 133.98614501953125
# Maximum depth value among detected vehicles: 492.6810302734375
# Detected vehicle depth at center: 524.2937622070312
# Detected vehicle depth at center: 140.02037048339844
# Maximum depth value among detected vehicles: 524.2937622070312
# Detected vehicle depth at center: 499.95574951171875
# Detected vehicle depth at center: 131.24429321289062
# Maximum depth value among detected vehicles: 499.95574951171875
# Detected vehicle depth at center: 127.55744934082031
# Maximum depth value among detected vehicles: 127.55744934082031
# Detected vehicle depth at center: 122.83141326904297
# Maximum depth value among detected vehicles: 122.83141326904297
# Detected vehicle depth at center: 128.76837158203125
# Maximum depth value among detected vehicles: 128.76837158203125
# Detected vehicle depth at center: 124.91404724121094
# Maximum depth value among detected vehicles: 124.91404724121094
# Detected vehicle depth at center: 123.2431411743164
# Maximum depth value among detected vehicles: 123.2431411743164
# Detected vehicle depth at center: 120.58683013916016
# Maximum depth value among detected vehicles: 120.58683013916016
# Detected vehicle depth at center: 116.29045104980469
# Maximum depth value among detected vehicles: 116.29045104980469
# Detected vehicle depth at center: 107.88841247558594
# Maximum depth value among detected vehicles: 107.88841247558594
# Detected vehicle depth at center: 124.61185455322266
# Maximum depth value among detected vehicles: 124.61185455322266
# Detected vehicle depth at center: 124.50261688232422
# Maximum depth value among detected vehicles: 124.50261688232422
# Detected vehicle depth at center: 124.03321838378906
# Maximum depth value among detected vehicles: 124.03321838378906
# Detected vehicle depth at center: 124.86335754394531
# Maximum depth value among detected vehicles: 124.86335754394531
# Detected vehicle depth at center: 122.38134002685547
# Maximum depth value among detected vehicles: 122.38134002685547
# Detected vehicle depth at center: 107.88617706298828
# Maximum depth value among detected vehicles: 107.88617706298828
# Detected vehicle depth at center: 113.13087463378906
# Maximum depth value among detected vehicles: 113.13087463378906
# Detected vehicle depth at center: 119.82852172851562
# Maximum depth value among detected vehicles: 119.82852172851562
# Detected vehicle depth at center: 120.49809265136719
# Maximum depth value among detected vehicles: 120.49809265136719
# Detected vehicle depth at center: 131.0469512939453
# Maximum depth value among detected vehicles: 131.0469512939453
# Detected vehicle depth at center: 126.95454406738281
# Maximum depth value among detected vehicles: 126.95454406738281
# Detected vehicle depth at center: 115.02537536621094
# Maximum depth value among detected vehicles: 115.02537536621094
# Detected vehicle depth at center: 123.53303527832031
# Maximum depth value among detected vehicles: 123.53303527832031
# Detected vehicle depth at center: 122.35951232910156
# Maximum depth value among detected vehicles: 122.35951232910156
# Detected vehicle depth at center: 130.23423767089844
# Maximum depth value among detected vehicles: 130.23423767089844
# Detected vehicle depth at center: 127.87963104248047
# Maximum depth value among detected vehicles: 127.87963104248047
# Detected vehicle depth at center: 127.77458953857422
# Maximum depth value among detected vehicles: 127.77458953857422
# Detected vehicle depth at center: 126.89369201660156
# Maximum depth value among detected vehicles: 126.89369201660156
# Detected vehicle depth at center: 114.82734680175781
# Maximum depth value among detected vehicles: 114.82734680175781
# Detected vehicle depth at center: 112.35066223144531
# Maximum depth value among detected vehicles: 112.35066223144531
# Detected vehicle depth at center: 126.45698547363281
# Detected vehicle depth at center: 117.7766342163086
# Maximum depth value among detected vehicles: 126.45698547363281
# Detected vehicle depth at center: 141.1571044921875
# Detected vehicle depth at center: 131.3207244873047
# Maximum depth value among detected vehicles: 141.1571044921875
# Detected vehicle depth at center: 140.9275360107422
# Maximum depth value among detected vehicles: 140.9275360107422
# Detected vehicle depth at center: 136.8481903076172
# Maximum depth value among detected vehicles: 136.8481903076172
# Detected vehicle depth at center: 128.6924591064453
# Maximum depth value among detected vehicles: 128.6924591064453
# Detected vehicle depth at center: 129.37562561035156
# Maximum depth value among detected vehicles: 129.37562561035156
# No vehicles detected.
# No vehicles detected.
# Detected vehicle depth at center: 172.64625549316406
# Maximum depth value among detected vehicles: 172.64625549316406
# Detected vehicle depth at center: 162.42921447753906
# Detected vehicle depth at center: 155.2100830078125
# Maximum depth value among detected vehicles: 162.42921447753906
# Detected vehicle depth at center: 156.05870056152344
# Maximum depth value among detected vehicles: 156.05870056152344
# Detected vehicle depth at center: 147.17324829101562
# Maximum depth value among detected vehicles: 147.17324829101562
# Detected vehicle depth at center: 157.6148681640625
# Detected vehicle depth at center: 135.74693298339844
# Maximum depth value among detected vehicles: 157.6148681640625
# Detected vehicle depth at center: 178.51596069335938
# Detected vehicle depth at center: 137.11563110351562
# Maximum depth value among detected vehicles: 178.51596069335938
# Detected vehicle depth at center: 195.4449920654297
# Detected vehicle depth at center: 159.3546142578125
# Maximum depth value among detected vehicles: 195.4449920654297
# Detected vehicle depth at center: 180.27069091796875
# Detected vehicle depth at center: 143.13470458984375
# Maximum depth value among detected vehicles: 180.27069091796875
# Detected vehicle depth at center: 160.93914794921875
# Detected vehicle depth at center: 151.06246948242188
# Maximum depth value among detected vehicles: 160.93914794921875
# Detected vehicle depth at center: 182.581787109375
# Detected vehicle depth at center: 150.2248077392578
# Maximum depth value among detected vehicles: 182.581787109375
# Detected vehicle depth at center: 138.1491241455078
# Detected vehicle depth at center: 122.85044860839844
# Maximum depth value among detected vehicles: 138.1491241455078
# Detected vehicle depth at center: 194.2361297607422
# Detected vehicle depth at center: 157.3993682861328
# Maximum depth value among detected vehicles: 194.2361297607422
# Detected vehicle depth at center: 143.01513671875
# Maximum depth value among detected vehicles: 143.01513671875
# Detected vehicle depth at center: 173.19534301757812
# Detected vehicle depth at center: 150.08816528320312
# Maximum depth value among detected vehicles: 173.19534301757812
# Detected vehicle depth at center: 169.45755004882812
# Maximum depth value among detected vehicles: 169.45755004882812
# Detected vehicle depth at center: 169.1248321533203
# Maximum depth value among detected vehicles: 169.1248321533203
# Detected vehicle depth at center: 193.43594360351562
# Maximum depth value among detected vehicles: 193.43594360351562
# Detected vehicle depth at center: 150.55458068847656
# Maximum depth value among detected vehicles: 150.55458068847656
# Detected vehicle depth at center: 175.4990234375
# Maximum depth value among detected vehicles: 175.4990234375
# Detected vehicle depth at center: 206.19537353515625
# Maximum depth value among detected vehicles: 206.19537353515625
# Detected vehicle depth at center: 211.1484832763672
# Maximum depth value among detected vehicles: 211.1484832763672
# Detected vehicle depth at center: 221.60589599609375
# Maximum depth value among detected vehicles: 221.60589599609375
# Detected vehicle depth at center: 238.69337463378906
# Maximum depth value among detected vehicles: 238.69337463378906
# Detected vehicle depth at center: 190.34925842285156
# Maximum depth value among detected vehicles: 190.34925842285156
# Detected vehicle depth at center: 194.46881103515625
# Maximum depth value among detected vehicles: 194.46881103515625
# Detected vehicle depth at center: 229.91453552246094
# Maximum depth value among detected vehicles: 229.91453552246094
# Detected vehicle depth at center: 266.4022216796875
# Maximum depth value among detected vehicles: 266.4022216796875
# Detected vehicle depth at center: 293.8973083496094
# Maximum depth value among detected vehicles: 293.8973083496094
# Detected vehicle depth at center: 300.5068054199219
# Maximum depth value among detected vehicles: 300.5068054199219
# Detected vehicle depth at center: 270.424560546875
# Maximum depth value among detected vehicles: 270.424560546875
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Detected vehicle depth at center: 313.5518493652344
# Maximum depth value among detected vehicles: 313.5518493652344
# Detected vehicle depth at center: 336.22021484375
# Maximum depth value among detected vehicles: 336.22021484375
# Detected vehicle depth at center: 330.8130798339844
# Maximum depth value among detected vehicles: 330.8130798339844
# Detected vehicle depth at center: 292.75347900390625
# Maximum depth value among detected vehicles: 292.75347900390625
# Detected vehicle depth at center: 332.8233337402344
# Maximum depth value among detected vehicles: 332.8233337402344
# Detected vehicle depth at center: 310.9016418457031
# Maximum depth value among detected vehicles: 310.9016418457031
# Detected vehicle depth at center: 323.08447265625
# Maximum depth value among detected vehicles: 323.08447265625
# Detected vehicle depth at center: 341.986328125
# Maximum depth value among detected vehicles: 341.986328125
# Detected vehicle depth at center: 326.541259765625
# Maximum depth value among detected vehicles: 326.541259765625
# Detected vehicle depth at center: 370.90179443359375
# Maximum depth value among detected vehicles: 370.90179443359375
# Detected vehicle depth at center: 387.5012512207031
# Maximum depth value among detected vehicles: 387.5012512207031
# Detected vehicle depth at center: 349.178466796875
# Maximum depth value among detected vehicles: 349.178466796875
# Detected vehicle depth at center: 379.1156921386719
# Maximum depth value among detected vehicles: 379.1156921386719
# Detected vehicle depth at center: 369.7553405761719
# Maximum depth value among detected vehicles: 369.7553405761719
# Detected vehicle depth at center: 362.16351318359375
# Maximum depth value among detected vehicles: 362.16351318359375
# Detected vehicle depth at center: 478.0372314453125
# Maximum depth value among detected vehicles: 478.0372314453125
# Detected vehicle depth at center: 490.95269775390625
# Maximum depth value among detected vehicles: 490.95269775390625
# Detected vehicle depth at center: 567.1484985351562
# Maximum depth value among detected vehicles: 567.1484985351562
# Detected vehicle depth at center: 557.9921875
# Maximum depth value among detected vehicles: 557.9921875
# Detected vehicle depth at center: 593.3004760742188
# Maximum depth value among detected vehicles: 593.3004760742188
# Detected vehicle depth at center: 606.494140625
# Maximum depth value among detected vehicles: 606.494140625
# Detected vehicle depth at center: 575.44677734375
# Maximum depth value among detected vehicles: 575.44677734375
# Detected vehicle depth at center: 614.0910034179688
# Maximum depth value among detected vehicles: 614.0910034179688
# Detected vehicle depth at center: 620.076171875
# Detected vehicle depth at center: 145.45492553710938
# Maximum depth value among detected vehicles: 620.076171875
# Detected vehicle depth at center: 668.8298950195312
# Maximum depth value among detected vehicles: 668.8298950195312
# Detected vehicle depth at center: 697.6738891601562
# Maximum depth value among detected vehicles: 697.6738891601562
# Detected vehicle depth at center: 687.38427734375
# Detected vehicle depth at center: 147.96728515625
# Maximum depth value among detected vehicles: 687.38427734375
# Detected vehicle depth at center: 634.7322387695312
# Detected vehicle depth at center: 141.07736206054688
# Maximum depth value among detected vehicles: 634.7322387695312
# Detected vehicle depth at center: 664.0890502929688
# Detected vehicle depth at center: 136.85072326660156
# Maximum depth value among detected vehicles: 664.0890502929688
# Detected vehicle depth at center: 660.9474487304688
# Detected vehicle depth at center: 140.3798065185547
# Maximum depth value among detected vehicles: 660.9474487304688
# Detected vehicle depth at center: 726.828369140625
# Detected vehicle depth at center: 141.46519470214844
# Maximum depth value among detected vehicles: 726.828369140625
# Detected vehicle depth at center: 685.5306396484375
# Detected vehicle depth at center: 140.34307861328125
# Maximum depth value among detected vehicles: 685.5306396484375
# Detected vehicle depth at center: 681.4090576171875
# Detected vehicle depth at center: 160.080078125
# Maximum depth value among detected vehicles: 681.4090576171875
# Detected vehicle depth at center: 698.7704467773438
# Detected vehicle depth at center: 152.24526977539062
# Maximum depth value among detected vehicles: 698.7704467773438
# Detected vehicle depth at center: 800.5689697265625
# Detected vehicle depth at center: 138.47250366210938
# Maximum depth value among detected vehicles: 800.5689697265625
# Detected vehicle depth at center: 703.87451171875
# Detected vehicle depth at center: 132.36988830566406
# Maximum depth value among detected vehicles: 703.87451171875
# Detected vehicle depth at center: 689.8609619140625
# Detected vehicle depth at center: 115.38089752197266
# Maximum depth value among detected vehicles: 689.8609619140625
# Detected vehicle depth at center: 904.498779296875
# Detected vehicle depth at center: 138.3200225830078
# Maximum depth value among detected vehicles: 904.498779296875
# Detected vehicle depth at center: 131.97293090820312
# Maximum depth value among detected vehicles: 131.97293090820312
# Detected vehicle depth at center: 119.32696533203125
# Maximum depth value among detected vehicles: 119.32696533203125
# Detected vehicle depth at center: 101.52799987792969
# Maximum depth value among detected vehicles: 101.52799987792969
# Detected vehicle depth at center: 96.69782257080078
# Maximum depth value among detected vehicles: 96.69782257080078
# Detected vehicle depth at center: 95.70460510253906
# Maximum depth value among detected vehicles: 95.70460510253906
# Detected vehicle depth at center: 92.97820281982422
# Maximum depth value among detected vehicles: 92.97820281982422
# Detected vehicle depth at center: 94.91353607177734
# Maximum depth value among detected vehicles: 94.91353607177734
# Detected vehicle depth at center: 91.61445617675781
# Maximum depth value among detected vehicles: 91.61445617675781
# Detected vehicle depth at center: 93.09028625488281
# Maximum depth value among detected vehicles: 93.09028625488281
# Detected vehicle depth at center: 95.37747955322266
# Maximum depth value among detected vehicles: 95.37747955322266
# Detected vehicle depth at center: 98.04244232177734
# Maximum depth value among detected vehicles: 98.04244232177734
# Detected vehicle depth at center: 100.38422393798828
# Maximum depth value among detected vehicles: 100.38422393798828
# Detected vehicle depth at center: 97.58233642578125
# Maximum depth value among detected vehicles: 97.58233642578125
# Detected vehicle depth at center: 100.28822326660156
# Maximum depth value among detected vehicles: 100.28822326660156
# Detected vehicle depth at center: 99.19698333740234
# Maximum depth value among detected vehicles: 99.19698333740234
# Detected vehicle depth at center: 100.88923645019531
# Maximum depth value among detected vehicles: 100.88923645019531
# Detected vehicle depth at center: 98.41302490234375
# Maximum depth value among detected vehicles: 98.41302490234375
# Detected vehicle depth at center: 98.77667236328125
# Maximum depth value among detected vehicles: 98.77667236328125
# Detected vehicle depth at center: 98.7418212890625
# Maximum depth value among detected vehicles: 98.7418212890625
# Detected vehicle depth at center: 99.63921356201172
# Maximum depth value among detected vehicles: 99.63921356201172
# Detected vehicle depth at center: 97.29826354980469
# Maximum depth value among detected vehicles: 97.29826354980469
# Detected vehicle depth at center: 97.92788696289062
# Maximum depth value among detected vehicles: 97.92788696289062
# Detected vehicle depth at center: 94.3411636352539
# Maximum depth value among detected vehicles: 94.3411636352539
# Detected vehicle depth at center: 95.63762664794922
# Maximum depth value among detected vehicles: 95.63762664794922
# Detected vehicle depth at center: 94.2027359008789
# Maximum depth value among detected vehicles: 94.2027359008789
# Detected vehicle depth at center: 94.69823455810547
# Maximum depth value among detected vehicles: 94.69823455810547
# Detected vehicle depth at center: 95.48975372314453
# Maximum depth value among detected vehicles: 95.48975372314453
# Detected vehicle depth at center: 96.14771270751953
# Maximum depth value among detected vehicles: 96.14771270751953
# Detected vehicle depth at center: 95.61265563964844
# Maximum depth value among detected vehicles: 95.61265563964844
# Detected vehicle depth at center: 95.19439697265625
# Maximum depth value among detected vehicles: 95.19439697265625
# Detected vehicle depth at center: 93.99288940429688
# Maximum depth value among detected vehicles: 93.99288940429688
# Detected vehicle depth at center: 97.62797546386719
# Maximum depth value among detected vehicles: 97.62797546386719
# Detected vehicle depth at center: 95.56526184082031
# Maximum depth value among detected vehicles: 95.56526184082031
# Detected vehicle depth at center: 101.25145721435547
# Maximum depth value among detected vehicles: 101.25145721435547
# Detected vehicle depth at center: 99.86100006103516
# Maximum depth value among detected vehicles: 99.86100006103516
# Detected vehicle depth at center: 103.64285278320312
# Maximum depth value among detected vehicles: 103.64285278320312
# Detected vehicle depth at center: 101.56819152832031
# Maximum depth value among detected vehicles: 101.56819152832031
# Detected vehicle depth at center: 101.29067993164062
# Maximum depth value among detected vehicles: 101.29067993164062
# Detected vehicle depth at center: 101.8692855834961
# Maximum depth value among detected vehicles: 101.8692855834961
# Detected vehicle depth at center: 103.43311309814453
# Maximum depth value among detected vehicles: 103.43311309814453
# No vehicles detected.
# Detected vehicle depth at center: 105.32635498046875
# Maximum depth value among detected vehicles: 105.32635498046875
# Detected vehicle depth at center: 106.43350982666016
# Maximum depth value among detected vehicles: 106.43350982666016
# Detected vehicle depth at center: 105.57704162597656
# Maximum depth value among detected vehicles: 105.57704162597656
# Detected vehicle depth at center: 104.38906860351562
# Maximum depth value among detected vehicles: 104.38906860351562
# Detected vehicle depth at center: 107.0155258178711
# Maximum depth value among detected vehicles: 107.0155258178711
# No vehicles detected.
# Detected vehicle depth at center: 106.15029907226562
# Maximum depth value among detected vehicles: 106.15029907226562
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# Detected vehicle depth at center: 99.55180358886719
# Maximum depth value among detected vehicles: 99.55180358886719
# Detected vehicle depth at center: 102.97472381591797
# Maximum depth value among detected vehicles: 102.97472381591797
# Detected vehicle depth at center: 98.88673400878906
# Maximum depth value among detected vehicles: 98.88673400878906
# Detected vehicle depth at center: 100.59378814697266
# Maximum depth value among detected vehicles: 100.59378814697266
# Detected vehicle depth at center: 107.85865783691406
# Maximum depth value among detected vehicles: 107.85865783691406
# Detected vehicle depth at center: 106.77978515625
# Maximum depth value among detected vehicles: 106.77978515625
# Detected vehicle depth at center: 104.94685363769531
# Maximum depth value among detected vehicles: 104.94685363769531
# Detected vehicle depth at center: 101.13223266601562
# Maximum depth value among detected vehicles: 101.13223266601562
# Detected vehicle depth at center: 104.03848266601562
# Maximum depth value among detected vehicles: 104.03848266601562
# Detected vehicle depth at center: 106.53498077392578
# Maximum depth value among detected vehicles: 106.53498077392578
# Detected vehicle depth at center: 101.9239501953125
# Maximum depth value among detected vehicles: 101.9239501953125
# Detected vehicle depth at center: 103.3167724609375
# Maximum depth value among detected vehicles: 103.3167724609375
# Detected vehicle depth at center: 115.63973236083984
# Maximum depth value among detected vehicles: 115.63973236083984
# Detected vehicle depth at center: 114.45487213134766
# Maximum depth value among detected vehicles: 114.45487213134766
# Detected vehicle depth at center: 112.63087463378906
# Maximum depth value among detected vehicles: 112.63087463378906
# Detected vehicle depth at center: 111.21987915039062
# Maximum depth value among detected vehicles: 111.21987915039062
# Detected vehicle depth at center: 117.73057556152344
# Maximum depth value among detected vehicles: 117.73057556152344
# Detected vehicle depth at center: 118.25470733642578
# Maximum depth value among detected vehicles: 118.25470733642578
# Detected vehicle depth at center: 118.20111846923828
# Maximum depth value among detected vehicles: 118.20111846923828
# Detected vehicle depth at center: 118.40235137939453
# Maximum depth value among detected vehicles: 118.40235137939453
# Detected vehicle depth at center: 117.93950653076172
# Maximum depth value among detected vehicles: 117.93950653076172
# Detected vehicle depth at center: 114.30760955810547
# Maximum depth value among detected vehicles: 114.30760955810547
# Detected vehicle depth at center: 116.55482482910156
# Maximum depth value among detected vehicles: 116.55482482910156
# Detected vehicle depth at center: 114.3388900756836
# Maximum depth value among detected vehicles: 114.3388900756836
# Detected vehicle depth at center: 116.40123748779297
# Maximum depth value among detected vehicles: 116.40123748779297
# Detected vehicle depth at center: 109.6285400390625
# Maximum depth value among detected vehicles: 109.6285400390625
# Detected vehicle depth at center: 119.70620727539062
# Maximum depth value among detected vehicles: 119.70620727539062
# Detected vehicle depth at center: 105.1172103881836
# Maximum depth value among detected vehicles: 105.1172103881836
# Detected vehicle depth at center: 102.74066925048828
# Maximum depth value among detected vehicles: 102.74066925048828
# Detected vehicle depth at center: 108.84921264648438
# Maximum depth value among detected vehicles: 108.84921264648438
# Detected vehicle depth at center: 106.72232055664062
# Maximum depth value among detected vehicles: 106.72232055664062
# Detected vehicle depth at center: 102.45630645751953
# Maximum depth value among detected vehicles: 102.45630645751953
# Detected vehicle depth at center: 109.92213439941406
# Maximum depth value among detected vehicles: 109.92213439941406
# Detected vehicle depth at center: 105.93843078613281
# Maximum depth value among detected vehicles: 105.93843078613281
# Detected vehicle depth at center: 108.990478515625
# Maximum depth value among detected vehicles: 108.990478515625
# Detected vehicle depth at center: 111.45393371582031
# Maximum depth value among detected vehicles: 111.45393371582031
# Detected vehicle depth at center: 105.01087951660156
# Maximum depth value among detected vehicles: 105.01087951660156
# Detected vehicle depth at center: 114.33524322509766
# Maximum depth value among detected vehicles: 114.33524322509766
# Detected vehicle depth at center: 120.09251403808594
# Maximum depth value among detected vehicles: 120.09251403808594
# Detected vehicle depth at center: 118.2961654663086
# Maximum depth value among detected vehicles: 118.2961654663086
# Detected vehicle depth at center: 119.32435607910156
# Maximum depth value among detected vehicles: 119.32435607910156
# Detected vehicle depth at center: 122.57183837890625
# Maximum depth value among detected vehicles: 122.57183837890625
# Detected vehicle depth at center: 121.15290069580078
# Maximum depth value among detected vehicles: 121.15290069580078
# Detected vehicle depth at center: 114.66697692871094
# Maximum depth value among detected vehicles: 114.66697692871094
# Detected vehicle depth at center: 121.58662414550781
# Maximum depth value among detected vehicles: 121.58662414550781
# Detected vehicle depth at center: 123.7197494506836
# Maximum depth value among detected vehicles: 123.7197494506836
# Detected vehicle depth at center: 123.7269287109375
# Maximum depth value among detected vehicles: 123.7269287109375
# Detected vehicle depth at center: 125.42252349853516
# Maximum depth value among detected vehicles: 125.42252349853516
# Detected vehicle depth at center: 128.3927764892578
# Maximum depth value among detected vehicles: 128.3927764892578
# Detected vehicle depth at center: 133.2698211669922
# Maximum depth value among detected vehicles: 133.2698211669922
# Detected vehicle depth at center: 122.11228942871094
# Maximum depth value among detected vehicles: 122.11228942871094
# Detected vehicle depth at center: 128.21229553222656
# Maximum depth value among detected vehicles: 128.21229553222656
# Detected vehicle depth at center: 125.75090026855469
# Detected vehicle depth at center: 116.46357727050781
# Maximum depth value among detected vehicles: 125.75090026855469
# Detected vehicle depth at center: 122.23338317871094
# Detected vehicle depth at center: 122.15485382080078
# Maximum depth value among detected vehicles: 122.23338317871094
# Detected vehicle depth at center: 118.96495819091797
# Detected vehicle depth at center: 118.52519989013672
# Maximum depth value among detected vehicles: 118.96495819091797
# Detected vehicle depth at center: 121.64864349365234
# Detected vehicle depth at center: 122.20829010009766
# Maximum depth value among detected vehicles: 122.20829010009766
# Detected vehicle depth at center: 122.9884262084961
# Detected vehicle depth at center: 124.40248107910156
# Maximum depth value among detected vehicles: 124.40248107910156
# Detected vehicle depth at center: 125.45765686035156
# Detected vehicle depth at center: 123.42952728271484
# Maximum depth value among detected vehicles: 125.45765686035156
# Detected vehicle depth at center: 132.9119415283203
# Detected vehicle depth at center: 130.63916015625
# Maximum depth value among detected vehicles: 132.9119415283203
# Detected vehicle depth at center: 135.37217712402344
# Detected vehicle depth at center: 129.9109344482422
# Maximum depth value among detected vehicles: 135.37217712402344
# Detected vehicle depth at center: 130.84915161132812
# Detected vehicle depth at center: 129.06947326660156
# Maximum depth value among detected vehicles: 130.84915161132812
# Detected vehicle depth at center: 133.49562072753906
# Detected vehicle depth at center: 129.08656311035156
# Maximum depth value among detected vehicles: 133.49562072753906
# Detected vehicle depth at center: 134.2802734375
# Detected vehicle depth at center: 133.802001953125
# Maximum depth value among detected vehicles: 134.2802734375
# Detected vehicle depth at center: 142.04547119140625
# Detected vehicle depth at center: 144.5468292236328
# Maximum depth value among detected vehicles: 144.5468292236328
# Detected vehicle depth at center: 155.0532684326172
# Detected vehicle depth at center: 143.11973571777344
# Maximum depth value among detected vehicles: 155.0532684326172
# Detected vehicle depth at center: 153.361083984375
# Detected vehicle depth at center: 138.5509033203125
# Maximum depth value among detected vehicles: 153.361083984375
# Detected vehicle depth at center: 142.77146911621094
# Detected vehicle depth at center: 137.8461151123047
# Maximum depth value among detected vehicles: 142.77146911621094
# Detected vehicle depth at center: 144.48739624023438
# Detected vehicle depth at center: 152.03094482421875
# Maximum depth value among detected vehicles: 152.03094482421875
# Detected vehicle depth at center: 122.5997543334961
# Detected vehicle depth at center: 159.33168029785156
# Maximum depth value among detected vehicles: 159.33168029785156
# Detected vehicle depth at center: 124.0383071899414
# Detected vehicle depth at center: 164.2293701171875
# Maximum depth value among detected vehicles: 164.2293701171875
# Detected vehicle depth at center: 126.89983367919922
# Maximum depth value among detected vehicles: 126.89983367919922
# Detected vehicle depth at center: 119.46129608154297
# Maximum depth value among detected vehicles: 119.46129608154297
# Detected vehicle depth at center: 121.04154205322266
# Detected vehicle depth at center: 164.00372314453125
# Maximum depth value among detected vehicles: 164.00372314453125
# Detected vehicle depth at center: 117.2983169555664
# Detected vehicle depth at center: 165.6613006591797
# Maximum depth value among detected vehicles: 165.6613006591797
# Detected vehicle depth at center: 117.78345489501953
# Detected vehicle depth at center: 164.10708618164062
# Maximum depth value among detected vehicles: 164.10708618164062
# Detected vehicle depth at center: 120.27293395996094
# Detected vehicle depth at center: 192.4475555419922
# Maximum depth value among detected vehicles: 192.4475555419922
# Detected vehicle depth at center: 121.04656219482422
# Detected vehicle depth at center: 185.8758087158203
# Maximum depth value among detected vehicles: 185.8758087158203
# ...
# Detected vehicle depth at center: 151.4680633544922
# Maximum depth value among detected vehicles: 427.4716491699219
# Detected vehicle depth at center: 385.0910949707031
# Detected vehicle depth at center: 160.95242309570312
# Maximum depth value among detected vehicles: 385.0910949707031
# Detected vehicle depth at center: 432.9093322753906
# Detected vehicle depth at center: 165.75364685058594
# Maximum depth value among detected vehicles: 432.9093322753906
# Detected vehicle depth at center: 438.8447570800781
# Detected vehicle depth at center: 173.283935546875
# Maximum depth value among detected vehicles: 438.8447570800781
# Detected vehicle depth at center: 446.3908386230469
# Detected vehicle depth at center: 186.14439392089844
# Maximum depth value among detected vehicles: 446.3908386230469
# Detected vehicle depth at center: 444.1410827636719
# Detected vehicle depth at center: 182.53341674804688
# Maximum depth value among detected vehicles: 444.1410827636719
# Detected vehicle depth at center: 482.0175476074219
# Maximum depth value among detected vehicles: 482.0175476074219
# Detected vehicle depth at center: 517.2367553710938
# Maximum depth value among detected vehicles: 517.2367553710938
# Detected vehicle depth at center: 538.5560302734375
# Detected vehicle depth at center: 191.057861328125
# Maximum depth value among detected vehicles: 538.5560302734375
# Detected vehicle depth at center: 515.4569702148438
# Detected vehicle depth at center: 178.12208557128906
# Maximum depth value among detected vehicles: 515.4569702148438
# Detected vehicle depth at center: 546.6976928710938
# Detected vehicle depth at center: 177.70132446289062
# Maximum depth value among detected vehicles: 546.6976928710938
# Detected vehicle depth at center: 518.7604370117188
# Detected vehicle depth at center: 168.9943389892578
# Maximum depth value among detected vehicles: 518.7604370117188
# Detected vehicle depth at center: 562.2289428710938
# Detected vehicle depth at center: 159.36309814453125
# Maximum depth value among detected vehicles: 562.2289428710938
# Detected vehicle depth at center: 557.7943725585938
# Detected vehicle depth at center: 148.57638549804688
# Maximum depth value among detected vehicles: 557.7943725585938
# Detected vehicle depth at center: 584.8131103515625
# Detected vehicle depth at center: 154.57969665527344
# Maximum depth value among detected vehicles: 584.8131103515625
# Detected vehicle depth at center: 632.0386352539062
# Detected vehicle depth at center: 153.03466796875
# Maximum depth value among detected vehicles: 632.0386352539062
# Detected vehicle depth at center: 628.6972045898438
# Detected vehicle depth at center: 134.04638671875
# Maximum depth value among detected vehicles: 628.6972045898438
# Detected vehicle depth at center: 682.3895263671875
# Detected vehicle depth at center: 123.79716491699219
# Maximum depth value among detected vehicles: 682.3895263671875
# Detected vehicle depth at center: 729.75927734375
# Detected vehicle depth at center: 140.49440002441406
# Maximum depth value among detected vehicles: 729.75927734375
# Detected vehicle depth at center: 633.9008178710938
# Detected vehicle depth at center: 133.7015838623047
# Maximum depth value among detected vehicles: 633.9008178710938
# Detected vehicle depth at center: 653.2174682617188
# Detected vehicle depth at center: 151.09133911132812
# Maximum depth value among detected vehicles: 653.2174682617188
# Detected vehicle depth at center: 720.245361328125
# Detected vehicle depth at center: 143.65859985351562
# Maximum depth value among detected vehicles: 720.245361328125
# Detected vehicle depth at center: 747.9089965820312
# Detected vehicle depth at center: 114.90994262695312
# Maximum depth value among detected vehicles: 747.9089965820312
# Detected vehicle depth at center: 599.0029907226562
# Detected vehicle depth at center: 159.17071533203125
# Maximum depth value among detected vehicles: 599.0029907226562
# Detected vehicle depth at center: 151.61068725585938
# Detected vehicle depth at center: 596.6891479492188
# Maximum depth value among detected vehicles: 596.6891479492188
# Detected vehicle depth at center: 575.287841796875
# Detected vehicle depth at center: 164.01394653320312
# Maximum depth value among detected vehicles: 575.287841796875
# Detected vehicle depth at center: 583.1524047851562
# Detected vehicle depth at center: 161.02957153320312
# Maximum depth value among detected vehicles: 583.1524047851562
# Detected vehicle depth at center: 676.2947998046875
# Detected vehicle depth at center: 174.68385314941406
# Maximum depth value among detected vehicles: 676.2947998046875
# Detected vehicle depth at center: 610.4851684570312
# Detected vehicle depth at center: 153.22756958007812
# Maximum depth value among detected vehicles: 610.4851684570312
# Detected vehicle depth at center: 727.866455078125
# Detected vehicle depth at center: 158.78688049316406
# Maximum depth value among detected vehicles: 727.866455078125
# Detected vehicle depth at center: 792.3657836914062
# Maximum depth value among detected vehicles: 792.3657836914062
# Detected vehicle depth at center: 925.9103393554688
# Maximum depth value among detected vehicles: 925.9103393554688
# No vehicles detected.
# No vehicles detected.
# Detected vehicle depth at center: 146.4998321533203
# Maximum depth value among detected vehicles: 146.4998321533203
# Detected vehicle depth at center: 146.6776885986328
# Maximum depth value among detected vehicles: 146.6776885986328
# Detected vehicle depth at center: 131.580322265625
# Maximum depth value among detected vehicles: 131.580322265625
# Detected vehicle depth at center: 125.01677703857422
# Maximum depth value among detected vehicles: 125.01677703857422
# Detected vehicle depth at center: 136.8626708984375
# Maximum depth value among detected vehicles: 136.8626708984375
# Detected vehicle depth at center: 133.18714904785156
# Maximum depth value among detected vehicles: 133.18714904785156
# Detected vehicle depth at center: 131.2743377685547
# Maximum depth value among detected vehicles: 131.2743377685547
# Detected vehicle depth at center: 117.8659896850586
# Maximum depth value among detected vehicles: 117.8659896850586
# Detected vehicle depth at center: 138.80126953125
# Maximum depth value among detected vehicles: 138.80126953125
# Detected vehicle depth at center: 146.00900268554688
# Maximum depth value among detected vehicles: 146.00900268554688
# Detected vehicle depth at center: 144.87168884277344
# Maximum depth value among detected vehicles: 144.87168884277344
# Detected vehicle depth at center: 137.34303283691406
# Maximum depth value among detected vehicles: 137.34303283691406
# No vehicles detected.
# No vehicles detected.
# Detected vehicle depth at center: 125.32522583007812
# Maximum depth value among detected vehicles: 125.32522583007812
# Detected vehicle depth at center: 132.4159393310547
# Maximum depth value among detected vehicles: 132.4159393310547
# Detected vehicle depth at center: 126.1352310180664
# Maximum depth value among detected vehicles: 126.1352310180664
# Detected vehicle depth at center: 131.99932861328125
# Maximum depth value among detected vehicles: 131.99932861328125
# Detected vehicle depth at center: 124.54850769042969
# Maximum depth value among detected vehicles: 124.54850769042969
# Detected vehicle depth at center: 140.06686401367188
# Maximum depth value among detected vehicles: 140.06686401367188
# Detected vehicle depth at center: 118.92138671875
# Maximum depth value among detected vehicles: 118.92138671875
# Detected vehicle depth at center: 128.92245483398438
# Maximum depth value among detected vehicles: 128.92245483398438
# Detected vehicle depth at center: 132.03614807128906
# Maximum depth value among detected vehicles: 132.03614807128906
# Detected vehicle depth at center: 137.63241577148438
# Maximum depth value among detected vehicles: 137.63241577148438
# Detected vehicle depth at center: 132.40621948242188
# Maximum depth value among detected vehicles: 132.40621948242188
# Detected vehicle depth at center: 132.9962158203125
# Maximum depth value among detected vehicles: 132.9962158203125
# Detected vehicle depth at center: 132.9942626953125
# Maximum depth value among detected vehicles: 132.9942626953125
# Detected vehicle depth at center: 123.8286361694336
# Maximum depth value among detected vehicles: 123.8286361694336
# Detected vehicle depth at center: 114.98780059814453
# Maximum depth value among detected vehicles: 114.98780059814453
# Detected vehicle depth at center: 126.70852661132812
# Maximum depth value among detected vehicles: 126.70852661132812
# Detected vehicle depth at center: 120.7061538696289
# Maximum depth value among detected vehicles: 120.7061538696289
# Detected vehicle depth at center: 124.85365295410156
# Maximum depth value among detected vehicles: 124.85365295410156
# Detected vehicle depth at center: 132.9553680419922
# Maximum depth value among detected vehicles: 132.9553680419922
# Detected vehicle depth at center: 129.0294189453125
# Maximum depth value among detected vehicles: 129.0294189453125
# Detected vehicle depth at center: 141.62533569335938
# Maximum depth value among detected vehicles: 141.62533569335938
# Detected vehicle depth at center: 140.35086059570312
# Maximum depth value among detected vehicles: 140.35086059570312
# Detected vehicle depth at center: 140.19992065429688
# Detected vehicle depth at center: 147.97311401367188
# Maximum depth value among detected vehicles: 147.97311401367188
# Detected vehicle depth at center: 113.8348388671875
# Maximum depth value among detected vehicles: 113.8348388671875
# Detected vehicle depth at center: 105.5849838256836
# Maximum depth value among detected vehicles: 105.5849838256836
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# No vehicles detected.
# Detected vehicle depth at center: 140.83424377441406
# Maximum depth value among detected vehicles: 140.83424377441406
# Detected vehicle depth at center: 158.53440856933594
# Maximum depth value among detected vehicles: 158.53440856933594
# Detected vehicle depth at center: 156.39622497558594
# Maximum depth value among detected vehicles: 156.39622497558594
# Detected vehicle depth at center: 157.5564727783203
# Maximum depth value among detected vehicles: 157.5564727783203
# Detected vehicle depth at center: 157.91273498535156
# Maximum depth value among detected vehicles: 157.91273498535156
# Detected vehicle depth at center: 150.07052612304688
# Maximum depth value among detected vehicles: 150.07052612304688
# Detected vehicle depth at center: 146.15904235839844
# Maximum depth value among detected vehicles: 146.15904235839844
# Detected vehicle depth at center: 148.93260192871094
# Maximum depth value among detected vehicles: 148.93260192871094
# Detected vehicle depth at center: 139.23892211914062
# Maximum depth value among detected vehicles: 139.23892211914062
# Detected vehicle depth at center: 143.76461791992188
# Maximum depth value among detected vehicles: 143.76461791992188
# Detected vehicle depth at center: 155.30758666992188
# Maximum depth value among detected vehicles: 155.30758666992188
# Detected vehicle depth at center: 156.4614715576172
# Maximum depth value among detected vehicles: 156.4614715576172
# Detected vehicle depth at center: 169.08749389648438
# Maximum depth value among detected vehicles: 169.08749389648438
# Detected vehicle depth at center: 164.95156860351562
# Maximum depth value among detected vehicles: 164.95156860351562
# Detected vehicle depth at center: 165.311767578125
# Maximum depth value among detected vehicles: 165.311767578125
# Detected vehicle depth at center: 161.50387573242188
# Maximum depth value among detected vehicles: 161.50387573242188
# Detected vehicle depth at center: 169.4926300048828
# Maximum depth value among detected vehicles: 169.4926300048828
# Detected vehicle depth at center: 165.4704132080078
# Maximum depth value among detected vehicles: 165.4704132080078
# Detected vehicle depth at center: 167.4027099609375
# Maximum depth value among detected vehicles: 167.4027099609375
# Detected vehicle depth at center: 172.86424255371094
# Maximum depth value among detected vehicles: 172.86424255371094
# Detected vehicle depth at center: 185.10585021972656
# Maximum depth value among detected vehicles: 185.10585021972656
# Detected vehicle depth at center: 206.4276123046875
# Maximum depth value among detected vehicles: 206.4276123046875
# Detected vehicle depth at center: 192.5723419189453
# Maximum depth value among detected vehicles: 192.5723419189453
# Detected vehicle depth at center: 177.9571990966797
# Maximum depth value among detected vehicles: 177.9571990966797
# Detected vehicle depth at center: 199.80923461914062
# Maximum depth value among detected vehicles: 199.80923461914062
# Detected vehicle depth at center: 225.52418518066406
# Maximum depth value among detected vehicles: 225.52418518066406
# Detected vehicle depth at center: 226.6306915283203
# Maximum depth value among detected vehicles: 226.6306915283203
# Detected vehicle depth at center: 267.3713073730469
# Maximum depth value among detected vehicles: 267.3713073730469
# Detected vehicle depth at center: 237.58465576171875
# Maximum depth value among detected vehicles: 237.58465576171875
# Detected vehicle depth at center: 235.95370483398438
# Maximum depth value among detected vehicles: 235.95370483398438
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Detected vehicle depth at center: 267.2296447753906
# Maximum depth value among detected vehicles: 267.2296447753906
# Detected vehicle depth at center: 287.3603210449219
# Maximum depth value among detected vehicles: 287.3603210449219
# Detected vehicle depth at center: 341.87060546875
# Maximum depth value among detected vehicles: 341.87060546875
# Detected vehicle depth at center: 338.00341796875
# Maximum depth value among detected vehicles: 338.00341796875
# Detected vehicle depth at center: 314.6009826660156
# Maximum depth value among detected vehicles: 314.6009826660156
# Detected vehicle depth at center: 334.7401428222656
# Maximum depth value among detected vehicles: 334.7401428222656
# Detected vehicle depth at center: 337.885009765625
# Maximum depth value among detected vehicles: 337.885009765625
# Detected vehicle depth at center: 354.6770324707031
# Maximum depth value among detected vehicles: 354.6770324707031
# Detected vehicle depth at center: 382.4610595703125
# Maximum depth value among detected vehicles: 382.4610595703125
# Detected vehicle depth at center: 391.5466613769531
# Maximum depth value among detected vehicles: 391.5466613769531
# Detected vehicle depth at center: 390.56280517578125
# Maximum depth value among detected vehicles: 390.56280517578125
# Detected vehicle depth at center: 424.3136901855469
# Maximum depth value among detected vehicles: 424.3136901855469
# Detected vehicle depth at center: 422.33001708984375
# Maximum depth value among detected vehicles: 422.33001708984375
# Detected vehicle depth at center: 438.63189697265625
# Maximum depth value among detected vehicles: 438.63189697265625
# Detected vehicle depth at center: 429.36602783203125
# Maximum depth value among detected vehicles: 429.36602783203125
# Detected vehicle depth at center: 487.654052734375
# Maximum depth value among detected vehicles: 487.654052734375
# Detected vehicle depth at center: 499.7138671875
# Maximum depth value among detected vehicles: 499.7138671875
# Detected vehicle depth at center: 528.1295166015625
# Maximum depth value among detected vehicles: 528.1295166015625
# Detected vehicle depth at center: 536.9786376953125
# Maximum depth value among detected vehicles: 536.9786376953125
# Detected vehicle depth at center: 537.8812866210938
# Maximum depth value among detected vehicles: 537.8812866210938
# Detected vehicle depth at center: 542.2582397460938
# Maximum depth value among detected vehicles: 542.2582397460938
# Detected vehicle depth at center: 569.3009643554688
# Maximum depth value among detected vehicles: 569.3009643554688
# Detected vehicle depth at center: 562.9749145507812
# Maximum depth value among detected vehicles: 562.9749145507812

# %%
play_warning_sound()
# Out:
# sh: 1: play: not found
